# %% [markdown]
# ## Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv(os.getcwd() + '/dataset/clean_creditcard.csv')
df.tail(3)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 889  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 890  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 891  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 889 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 890 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 891  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#           V24       V25       V26       V27       V28  Class_Category  \
# 889  0.032070 -0.739695  0.471111  0.385107  0.194361               1
# 890 -0.183659 -0.328168  0.606116  0.884876 -0.253700               1
# 891 -0.450261  0.313267 -0.289617  0.002988 -0.015309               1
#
#      Stan_Amount
# 889    -0.041818
# 890     0.625675
# 891    -0.183058
#
# [3 rows x 31 columns]

# %% [markdown]
# ## Visual

# %%
fnfTransactions = df["Class_Category"].value_counts()
fnfTransactions
# Out:
# Class_Category
# 0    446
# 1    446
# Name: count, dtype: int64

# %%
plt.xlabel("Class")
plt.ylabel("Number of Observations")
fnfTransactions.plot(kind = 'bar',title = 'Frequency by observation number')
plt.show()

# %%
plt.xlabel("Class")
plt.ylabel("Number of Observations")
fnfTransactions.plot(kind = 'pie',title = 'Frequency by observation number')
plt.show()

# %%
df['Stan_Amount'].hist()
plt.xlabel("Standarized Amount")
plt.ylabel("Number of Observations")
plt.show()

# %%
df['Time'].hist()
plt.xlabel("Time")
plt.ylabel("Number of Observations")
plt.show()

# %%
ax = df.boxplot(column=["Stan_Amount"], by="Class_Category", grid=False)
ax.set_xlabel("Class_Category")
ax.set_ylabel("Standarized Amount")
plt.show()

# %%
plt.scatter(df.loc[df['Class_Category'] == 0]['V1'], df.loc[df['Class_Category'] == 0]['V2'],alpha=0.5, linewidth=0.15)
plt.scatter(df.loc[df['Class_Category'] == 1]['V1'], df.loc[df['Class_Category'] == 1]['V2'],alpha=0.5, linewidth=0.15,c='r')
plt.show()
