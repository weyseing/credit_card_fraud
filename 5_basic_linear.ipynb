# %% [markdown]
# ## Library

# %%
from numpy.random import default_rng
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Dummy Dataset

# %%
rg = default_rng(12345)
X = rg.uniform(low=0.0, high=20.0, size=(2000,))
X
# Out:
# array([ 4.54672045,  6.33516679, 15.94730915, ...,  9.35681476,
#         8.56236604,  8.79004056])

# %%
slope = 0.2
intercept = -1.2
y = slope * X + intercept + rg.normal(loc=0.0, scale=1.0, size=(2000,))

# %%
plt.figure(figsize=(10, 5))  
plt.scatter(X, y, s=2)
plt.xlabel('X') 
plt.ylabel('y') 
plt.show()

# %% [markdown]
# ## Model Fitting

# %%
lin_reg = LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None)

# %%
lin_reg.fit(X.reshape(-1,1), y)
print(lin_reg.intercept_)
print(lin_reg.coef_)
# Out:
# -1.1546801413339605
# [0.19513902]

# %% [markdown]
# ## Model Predict

# %%
y_pred = lin_reg.predict(X.reshape(-1,1))

# %%
plt.figure(figsize=(10, 5))  
plt.scatter(X, y, s=2)
plt.plot(X, y_pred,'g')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
